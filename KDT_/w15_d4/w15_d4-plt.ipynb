# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8,8), dpi=200)

df_ = pd.read_csv("./Dv1_N-R.csv")

sns.set(style='darkgrid')

sns.lineplot(x='epoch', y='with_mask', data=df_)
sns.lineplot(x='epoch', y='without_mask', data=df_)
sns.lineplot(x='epoch', y='total', data=df_)


# sns.lineplot(x='epoch', y='with_mask', data=df_2)
# sns.lineplot(x='epoch', y='without_mask', data=df_2)
# sns.lineplot(x='epoch', y='total', data=df_2, hue='Agumented')
# sns.lineplot(x='epoch', y='total', data=df_2)

plt.legend(labels=['with mask', 'without mask', 'total'])

# plt.xlim((0,2000000))
plt.xlabel('epoch')
plt.ylabel('FID score')


plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8,8), dpi=200)

df_ = pd.read_csv("./Dv1_N-R.csv")
df_['epoch'] = df_['epoch'] * 18000
df_2 = pd.read_csv("./Dv2_N-R.csv")
df_2['epoch'] = df_2['epoch'] * 40000

sns.set(style='darkgrid')

# sns.lineplot(x='epoch', y='with_mask', data=df_)
# sns.lineplot(x='epoch', y='without_mask', data=df_)
# sns.lineplot(x='epoch', y='total', data=df_, 'Original' )
sns.lineplot(x='epoch', y='total', data=df_)


# sns.lineplot(x='epoch', y='with_mask', data=df_2)
# sns.lineplot(x='epoch', y='without_mask', data=df_2)
# sns.lineplot(x='epoch', y='total', data=df_2, hue='Agumented')
sns.lineplot(x='epoch', y='total', data=df_2)

plt.legend(labels=['original', 'agumented'])

plt.xlim((0,2000000))
plt.xlabel('num training image')
plt.ylabel('total FID score')


plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8,8), dpi=200)

df_ = pd.read_csv("./Dv2_N-R.csv")
# df_['epoch'] = df_['epoch'] * 18000
df_2 = pd.read_csv("./Dv2_Lr-R.csv")
# df_2['epoch'] = df_2['epoch'] * 40000

sns.set(style='darkgrid')

# sns.lineplot(x='epoch', y='with_mask', data=df_)
# sns.lineplot(x='epoch', y='without_mask', data=df_)
# sns.lineplot(x='epoch', y='total', data=df_, 'Original' )
sns.lineplot(x='epoch', y='total', data=df_)


# sns.lineplot(x='epoch', y='with_mask', data=df_2)
# sns.lineplot(x='epoch', y='without_mask', data=df_2)
# sns.lineplot(x='epoch', y='total', data=df_2, hue='Agumented')
sns.lineplot(x='epoch', y='total', data=df_2)

plt.legend(labels=['original', 'replaced to "Relu"'])

# plt.xlim((0,2000000))
plt.xlabel('epoch')
plt.ylabel('total FID score')


plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8,8), dpi=200)

df_ = pd.read_csv("./Dv2_N-R.csv")
# df_.to_csv("./Dv2_N-Rtemp.csv")
# df_['epoch'] = df_['epoch'] * 18000
df_2 = pd.read_csv("./Dv2_Ct-Rv.csv")
# df_2['epoch'] = df_2['epoch'] * 40000

sns.set(style='darkgrid')

# sns.lineplot(x='epoch', y='with_mask', data=df_)
# sns.lineplot(x='epoch', y='without_mask', data=df_)
# sns.lineplot(x='epoch', y='total', data=df_, 'Original' )
sns.lineplot(x='epoch', y='total', data=df_)


# sns.lineplot(x='epoch', y='with_mask', data=df_2)
# sns.lineplot(x='epoch', y='without_mask', data=df_2)
# sns.lineplot(x='epoch', y='total', data=df_2, hue='Agumented')
sns.lineplot(x='epoch', y='total', data=df_2)

plt.legend(labels=['original', 'replaced to ConvTranspose2d'])

# plt.xlim((0,2000000))
plt.xlabel('epoch')
plt.ylabel('total FID score')


plt.show()
