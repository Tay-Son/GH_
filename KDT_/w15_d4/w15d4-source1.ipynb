# %% [markdown]
# ### <b>실전 프로젝트 - GAN을 이용한 얼굴 마스크 이미지 생성 </b>
#
# * 마스크를 착용한 이미지와 마스크를 착용하지 않은 얼굴 이미지를 생성하는 <b>생성 모델</b>을 만드세요.
# * 다음의 두 가지 대표적인 GAN 모델을 실습합니다.
#     1. [Generative Adversarial Networks (NIPS 2014)](https://arxiv.org/abs/1406.2661)
#     2. [Deep Convolutional Generative Adversarial Networks (ICLR 2016)](https://arxiv.org/abs/1511.06434)
# * 또한 자신이 원하는 아키텍처의 GAN 모델을 직접 선택하여 학습하는 실습을 진행합니다.
# * 본 프로젝트는 <b>최종적으로 높은 점수(score)를 얻는 것이 목표</b>입니다.
#     * <b>Problem</b>이라고 명시된 부분의 소스코드만 작성합니다.
#     * <b>알아보기</b>라고 명시된 부분은 단순히 읽고 실행하면 됩니다.
# * 최종적으로 <b>팀 단위로 제출할 파일</b>은 다음과 같습니다.
#     1. PPT 파일: 사용한 모델과 최종적인 FID 점수에 대한 설명을 포함하기
#     2. Colab Notebook 파일: <b>[파일]</b> - <b>[다운로드]</b> - <b>[.ipynb 다운로드]</b>
#     3. 최종 결과 이미지(마스크 착용 1,000개 및 마스크 미착용 1,000개)가 포함된 압축 파일
# * 자세한 평가 기준은 <b>Problem 1</b>에서 확인하세요.

# %% [markdown]
# #### <b>(알아보기) 데이터셋 다운로드</b>
#
# * 실습을 위해 [<b>Face Mask Classification</b> 데이터셋](https://github.com/ndb796/Face-Mask-Classification-20000-Dataset)을 불러옵니다.
# * 데이터셋은 흑백(grayscale) 이미지로 구성됩니다.
# * GPU 가속기를 이용하기 위해 <b>[런타임]</b> - <b>[런타임 유형 변경]</b> - <b>[GPU]</b>를 선택합니다.
# * <b>학습 데이터셋</b>
#     * 마스크 착용(with mask): 9,000장
#     * 마스크 미착용(wihtout mask): 9,000장
# * <b>테스트 데이터셋</b>
#     * 마스크 착용(with mask): 1,000장
#     * 마스크 미착용(wihtout mask): 1,000장

# %%
# !git clone https://github.com/ndb796/Face-Mask-Classification-20000-Dataset
# Out:
# Cloning into 'Face-Mask-Classification-20000-Dataset'...
# Updating files:  11% (2383/20001)
# Updating files:  12% (2401/20001)
# Updating files:  13% (2601/20001)
# Updating files:  14% (2801/20001)
# Updating files:  15% (3001/20001)
# Updating files:  16% (3201/20001)
# Updating files:  17% (3401/20001)
# Updating files:  18% (3601/20001)
# Updating files:  19% (3801/20001)
# Updating files:  20% (4001/20001)
# Updating files:  21% (4201/20001)
# Updating files:  22% (4401/20001)
# Updating files:  23% (4601/20001)
# Updating files:  23% (4649/20001)
# Updating files:  24% (4801/20001)
# Updating files:  25% (5001/20001)
# Updating files:  26% (5201/20001)
# Updating files:  27% (5401/20001)
# Updating files:  28% (5601/20001)
# Updating files:  29% (5801/20001)
# Updating files:  30% (6001/20001)
# Updating files:  31% (6201/20001)
# Updating files:  32% (6401/20001)
# Updating files:  33% (6601/20001)
# Updating files:  34% (6801/20001)
# Updating files:  34% (6913/20001)
# Updating files:  35% (7001/20001)
# Updating files:  36% (7201/20001)
# Updating files:  37% (7401/20001)
# Updating files:  38% (7601/20001)
# Updating files:  39% (7801/20001)
# Updating files:  40% (8001/20001)
# Updating files:  41% (8201/20001)
# Updating files:  42% (8401/20001)
# Updating files:  43% (8601/20001)
# Updating files:  44% (8801/20001)
# Updating files:  44% (8919/20001)
# Updating files:  45% (9001/20001)
# Updating files:  46% (9201/20001)
# Updating files:  47% (9401/20001)
# Updating files:  48% (9601/20001)
# Updating files:  49% (9801/20001)
# Updating files:  50% (10001/20001)
# Updating files:  51% (10201/20001)
# Updating files:  52% (10401/20001)
# Updating files:  53% (10601/20001)
# Updating files:  54% (10801/20001)
# Updating files:  55% (11001/20001)
# Updating files:  56% (11201/20001)
# Updating files:  57% (11401/20001)
# Updating files:  58% (11601/20001)
# Updating files:  59% (11801/20001)
# Updating files:  60% (12001/20001)
# Updating files:  61% (12201/20001)
# Updating files:  62% (12401/20001)
# Updating files:  63% (12601/20001)
# Updating files:  64% (12801/20001)
# Updating files:  65% (13001/20001)
# Updating files:  65% (13150/20001)
# Updating files:  66% (13201/20001)
# Updating files:  67% (13401/20001)
# Updating files:  68% (13601/20001)
# Updating files:  69% (13801/20001)
# Updating files:  70% (14001/20001)
# Updating files:  71% (14201/20001)
# Updating files:  72% (14401/20001)
# Updating files:  73% (14601/20001)
# Updating files:  74% (14801/20001)
# Updating files:  75% (15001/20001)
# Updating files:  76% (15201/20001)
# Updating files:  76% (15392/20001)
# Updating files:  77% (15401/20001)
# Updating files:  78% (15601/20001)
# Updating files:  79% (15801/20001)
# Updating files:  80% (16001/20001)
# Updating files:  81% (16201/20001)
# Updating files:  82% (16401/20001)
# Updating files:  83% (16601/20001)
# Updating files:  84% (16801/20001)
# Updating files:  85% (17001/20001)
# Updating files:  86% (17201/20001)
# Updating files:  87% (17401/20001)
# Updating files:  88% (17601/20001)
# Updating files:  88% (17680/20001)
# Updating files:  89% (17801/20001)
# Updating files:  90% (18001/20001)
# Updating files:  91% (18201/20001)
# Updating files:  92% (18401/20001)
# Updating files:  93% (18601/20001)
# Updating files:  94% (18801/20001)
# Updating files:  95% (19001/20001)
# Updating files:  96% (19201/20001)
# Updating files:  97% (19401/20001)
# Updating files:  98% (19601/20001)
# Updating files:  99% (19801/20001)
# Updating files:  99% (19925/20001)
# Updating files: 100% (20001/20001)
# Updating files: 100% (20001/20001), done.

# %% [markdown]
# #### <b>(알아보기) 필요한 라이브러리 불러오기</b>
#
# * 실습을 위한 PyTorch 라이브러리를 불러옵니다.

# %%
import os
import time
import matplotlib.pyplot as plt
from PIL import Image

import torch
import torch.nn as nn

from torchvision import datasets
import torchvision.transforms as transforms
from torchvision.utils import save_image

# %% [markdown]
# #### <b>(알아보기) 학습 이미지 시각화</b>
#
# * 학습할 이미지 중에서 원하는 이미지를 골라 시각화합니다.

# %%
# 마스크를 쓴 이미지 출력
image = Image.open('./Face-Mask-Classification-20000-Dataset/train/with_mask/with-mask-default-mask-seed0030.png')
print("이미지 크기:", image.size)

plt.imshow(image, cmap='gray')
plt.show()

# 마스크를 쓰지 않은 이미지 출력
image = Image.open('./Face-Mask-Classification-20000-Dataset/train/without_mask/seed0030.png')
print("이미지 크기:", image.size)

plt.imshow(image, cmap='gray')
plt.show()
# Out:
# 이미지 크기: (224, 224)
# 이미지 크기: (224, 224)

# %% [markdown]
# #### <b>(알아보기) 데이터셋 불러오기</b>
#
# * 학습할 이미지 크기: 1 X 64 X 64

# %%
transforms_train = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.Grayscale(1),
    transforms.ToTensor(),
    transforms.Normalize((0.5), (0.5)) # normalization
])

data_dir = './Face-Mask-Classification-20000-Dataset/'
train_dataset = datasets.ImageFolder(os.path.join(data_dir, 'train'), transforms_train)
train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True, num_workers=2)
print('Train dataset size:', len(train_dataset))

class_names = train_dataset.classes
print('Class names:', class_names)
# Out:
# Train dataset size: 18000
# Class names: ['with_mask', 'without_mask']

# %% [markdown]
# #### <b>(알아보기) 기본적인 GAN 실습 - 모델 정의</b>
#
# * 논문 제목: [Generative Adversarial Networks](https://arxiv.org/abs/1406.2661) <b>(NIPS 2014)</b>
# * 가장 기본적인 GAN 모델을 학습해보는 실습을 진행합니다.
#     * 마스크 착용 여부를 선택하기 위해 <b>조건부(conditional) GAN</b>을 이용합니다.
#     * <b>Reference</b>: [Conditional Generative Adversarial Nets (2014)](https://arxiv.org/abs/1411.1784)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * 생성자(Generator) 및 판별자(Discriminator) 모델을 정의합니다.
#     * 생성자 클래스: SimpleGenerator
#     * 판별자 클래스: SimpleDiscriminator
# * 본 소스코드는 원본 논문에서 제안한 아키텍처와 유사한 아키텍처를 이용합니다.
# * <b>Reference</b>: [PyTorch GAN 예시 코드](https://github.com/eriklindernoren/PyTorch-GAN/blob/master/implementations/gan/gan.py)

# %%
latent_dim = 100
n_classes = 2


# 생성자(Generator) 클래스 정의
class SimpleGenerator(nn.Module):
    def __init__(self):
        super(SimpleGenerator, self).__init__()

        # 레이블 정보를 임베딩 차원으로 매핑하여 사용
        self.label_embed = nn.Embedding(n_classes, n_classes)

        # 하나의 블록(block) 정의
        def block(input_dim, output_dim, normalize=True):
            layers = [nn.Linear(input_dim, output_dim)]
            if normalize:
                # 배치 정규화(batch normalization) 수행(차원 동일)
                layers.append(nn.BatchNorm1d(output_dim, 0.8))
            layers.append(nn.LeakyReLU(0.2, inplace=True))
            return layers

        # 생성자 모델은 연속적인 여러 개의 블록을 가짐
        self.model = nn.Sequential(
            *block(latent_dim + n_classes, 128, normalize=False),
            *block(128, 256),
            *block(256, 512),
            *block(512, 1024),
            *block(1024, 2048),
            nn.Linear(2048, 1 * 64 * 64),
            nn.Tanh()
        )

    def forward(self, noise, labels):
        # 노이즈(noise) 벡터와 레이블 임베딩을 순차적으로 연결하여 입력
        inputs = torch.cat((noise, self.label_embed(labels)), -1)
        img = self.model(inputs)
        img = img.view(img.size(0), 1, 64, 64)
        return img


# 판별자(Discriminator) 클래스 정의
class SimpleDiscriminator(nn.Module):
    def __init__(self):
        super(SimpleDiscriminator, self).__init__()

        # 레이블 정보를 임베딩 차원으로 매핑하여 사용
        self.label_embed = nn.Embedding(n_classes, n_classes)

        self.model = nn.Sequential(
            nn.Linear(1 * 64 * 64 + n_classes, 512),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(512, 512),
            nn.Dropout(0.4),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(512, 512),
            nn.Dropout(0.4),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(512, 512),
            nn.Dropout(0.4),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(512, 1),
        )

    # 이미지에 대한 판별 결과를 반환
    def forward(self, img, labels):
        flattened = img.view(img.size(0), -1)
        # 이미지 벡터와 레이블 임베딩을 순차적으로 연결하여 입력
        inputs = torch.cat((flattened, self.label_embed(labels)), -1)
        output = self.model(inputs)

        return output

# %% [markdown]
# #### <b>(알아보기) 기본적인 GAN 실습 - 모델 학습 및 샘플링</b>
#
# * 학습을 위해 생성자와 판별자 모델을 초기화합니다.
# * 적절한 하이퍼 파라미터를 설정합니다.

# %%
# 생성자(generator)와 판별자(discriminator) 초기화
simple_generator = SimpleGenerator()
simple_discriminator = SimpleDiscriminator()

simple_generator.cuda()
simple_discriminator.cuda()

# 손실 함수(loss function)
adversarial_loss = nn.MSELoss()
adversarial_loss.cuda()

# 학습률(learning rate) 설정
lr = 0.0002

# 생성자와 판별자를 위한 최적화 함수
optimizer_G = torch.optim.Adam(simple_generator.parameters(), lr=lr, betas=(0.5, 0.999))
optimizer_D = torch.optim.Adam(simple_discriminator.parameters(), lr=lr, betas=(0.5, 0.999))

# %% [markdown]
# * 모델을 학습하면서 주기적으로 샘플링하여 결과를 확인할 수 있습니다.

# %%
# !mkdir -p ./results/simple/

n_epochs = 100 # 학습의 횟수(epoch) 설정
sample_interval = 500 # 몇 번의 배치(batch)마다 결과를 출력할 것인지 설정
start_time = time.time()

for epoch in range(n_epochs):
    for i, (imgs, labels) in enumerate(train_dataloader):

        # 진짜(real) 이미지와 가짜(fake) 이미지에 대한 정답 레이블 생성
        real = torch.cuda.FloatTensor(imgs.shape[0], 1).fill_(1.0) # 진짜(real): 1
        fake = torch.cuda.FloatTensor(imgs.shape[0], 1).fill_(0.0) # 가짜(fake): 0

        real_imgs = imgs.cuda()
        labels = labels.cuda()

        """ 생성자(generator)를 학습합니다. """
        optimizer_G.zero_grad()

        # 랜덤 노이즈(noise) 및 랜덤 레이블(label) 샘플링
        z = torch.normal(mean=0, std=1, size=(imgs.shape[0], latent_dim)).cuda()
        generated_labels = torch.randint(0, n_classes, (imgs.shape[0],)).cuda()

        # 이미지 생성
        generated_imgs = simple_generator(z, generated_labels)

        # 생성자(generator)의 손실(loss) 값 계산
        g_loss = adversarial_loss(simple_discriminator(generated_imgs, generated_labels), real)

        # 생성자(generator) 업데이트
        g_loss.backward()
        optimizer_G.step()

        """ 판별자(discriminator)를 학습합니다. """
        optimizer_D.zero_grad()

        # 판별자(discriminator)의 손실(loss) 값 계산
        real_loss = adversarial_loss(simple_discriminator(real_imgs, labels), real)
        fake_loss = adversarial_loss(simple_discriminator(generated_imgs.detach(), generated_labels), fake)
        d_loss = (real_loss + fake_loss) / 2

        # 판별자(discriminator) 업데이트
        d_loss.backward()
        optimizer_D.step()

        done = epoch * len(train_dataloader) + i
        if done % sample_interval == 0:
            # 클래스당 8개의 이미지를 생성하여 2 X 8 격자 이미지에 출력
            z = torch.normal(mean=0, std=1, size=(n_classes * 8, latent_dim)).cuda()
            labels = torch.LongTensor([i for i in range(n_classes) for _ in range(8)]).cuda()
            generated_imgs = simple_generator(z, labels)
            save_image(generated_imgs, f"./results/simple/{done}.png", nrow=8, normalize=True)

    # 하나의 epoch이 끝날 때마다 로그(log) 출력
    print(f"[Epoch {epoch}/{n_epochs}] [D loss: {d_loss.item():.6f}] [G loss: {g_loss.item():.6f}] [Elapsed time: {time.time() - start_time:.2f}s]")
# Out:
# [Epoch 0/100] [D loss: 0.146478] [G loss: 0.503309] [Elapsed time: 29.85s]
# [Epoch 1/100] [D loss: 0.134537] [G loss: 0.467172] [Elapsed time: 41.51s]
# [Epoch 2/100] [D loss: 0.209542] [G loss: 0.718475] [Elapsed time: 53.19s]
# [Epoch 3/100] [D loss: 0.157070] [G loss: 0.303105] [Elapsed time: 64.89s]
# [Epoch 4/100] [D loss: 0.174831] [G loss: 0.322348] [Elapsed time: 76.54s]
# [Epoch 5/100] [D loss: 0.218403] [G loss: 0.315424] [Elapsed time: 88.42s]
# [Epoch 6/100] [D loss: 0.252308] [G loss: 0.667330] [Elapsed time: 100.72s]
# [Epoch 7/100] [D loss: 0.230069] [G loss: 0.666488] [Elapsed time: 112.46s]
# [Epoch 8/100] [D loss: 0.185340] [G loss: 0.465255] [Elapsed time: 124.34s]
# [Epoch 9/100] [D loss: 0.164728] [G loss: 0.438685] [Elapsed time: 136.06s]
# [Epoch 10/100] [D loss: 0.204003] [G loss: 0.543557] [Elapsed time: 147.78s]
# [Epoch 11/100] [D loss: 0.232662] [G loss: 0.472129] [Elapsed time: 159.48s]
# [Epoch 12/100] [D loss: 0.195339] [G loss: 0.470111] [Elapsed time: 171.19s]
# [Epoch 13/100] [D loss: 0.182009] [G loss: 0.349819] [Elapsed time: 182.75s]
# [Epoch 14/100] [D loss: 0.143632] [G loss: 0.380533] [Elapsed time: 194.53s]
# [Epoch 15/100] [D loss: 0.215291] [G loss: 0.276453] [Elapsed time: 206.26s]
# [Epoch 16/100] [D loss: 0.152238] [G loss: 0.541753] [Elapsed time: 217.95s]
# [Epoch 17/100] [D loss: 0.127578] [G loss: 0.483808] [Elapsed time: 229.85s]
# [Epoch 18/100] [D loss: 0.214751] [G loss: 0.348027] [Elapsed time: 241.43s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [9], in <cell line: 7>()
#       5 start_time = time.time()
#       7 for epoch in range(n_epochs):
# ----> 8     for i, (imgs, labels) in enumerate(train_dataloader):
#       9
#      10         # 진짜(real) 이미지와 가짜(fake) 이미지에 대한 정답 레이블 생성
#      11         real = torch.cuda.FloatTensor(imgs.shape[0], 1).fill_(1.0) # 진짜(real): 1
#      12         fake = torch.cuda.FloatTensor(imgs.shape[0], 1).fill_(0.0) # 가짜(fake): 0
#
# File ~\anaconda3\lib\site-packages\torch\utils\data\dataloader.py:521, in _BaseDataLoaderIter.__next__(self)
#     519 if self._sampler_iter is None:
#     520     self._reset()
# --> 521 data = self._next_data()
#     522 self._num_yielded += 1
#     523 if self._dataset_kind == _DatasetKind.Iterable and \
#     524         self._IterableDataset_len_called is not None and \
#     525         self._num_yielded > self._IterableDataset_len_called:
#
# File ~\anaconda3\lib\site-packages\torch\utils\data\dataloader.py:1186, in _MultiProcessingDataLoaderIter._next_data(self)
#    1183     return self._process_data(data)
#    1185 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1186 idx, data = self._get_data()
#    1187 self._tasks_outstanding -= 1
#    1188 if self._dataset_kind == _DatasetKind.Iterable:
#    1189     # Check for _IterableDatasetStopIteration
#
# File ~\anaconda3\lib\site-packages\torch\utils\data\dataloader.py:1152, in _MultiProcessingDataLoaderIter._get_data(self)
#    1148     # In this case, `self._data_queue` is a `queue.Queue`,. But we don't
#    1149     # need to call `.task_done()` because we don't use `.join()`.
#    1150 else:
#    1151     while True:
# -> 1152         success, data = self._try_get_data()
#    1153         if success:
#    1154             return data
#
# File ~\anaconda3\lib\site-packages\torch\utils\data\dataloader.py:990, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#     977 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#     978     # Tries to fetch data from `self._data_queue` once for a given timeout.
#     979     # This can also be used as inner loop of fetching without timeout, with
#    (...)
#     987     # Returns a 2-tuple:
#     988     #   (bool: whether successfully get data, any: data if successful else None)
#     989     try:
# --> 990         data = self._data_queue.get(timeout=timeout)
#     991         return (True, data)
#     992     except Exception as e:
#     993         # At timeout and error, we manually check whether any worker has
#     994         # failed. Note that this is the only mechanism for Windows to detect
#     995         # worker failures.
#
# File ~\anaconda3\lib\multiprocessing\queues.py:107, in Queue.get(self, block, timeout)
#     105 if block:
#     106     timeout = deadline - time.monotonic()
# --> 107     if not self._poll(timeout):
#     108         raise Empty
#     109 elif not self._poll():
#
# File ~\anaconda3\lib\multiprocessing\connection.py:257, in _ConnectionBase.poll(self, timeout)
#     255 self._check_closed()
#     256 self._check_readable()
# --> 257 return self._poll(timeout)
#
# File ~\anaconda3\lib\multiprocessing\connection.py:330, in PipeConnection._poll(self, timeout)
#     327 if (self._got_empty_message or
#     328             _winapi.PeekNamedPipe(self._handle)[0] != 0):
#     329     return True
# --> 330 return bool(wait([self], timeout))
#
# File ~\anaconda3\lib\multiprocessing\connection.py:879, in wait(object_list, timeout)
#     876                 ready_objects.add(o)
#     877                 timeout = 0
# --> 879     ready_handles = _exhaustive_wait(waithandle_to_obj.keys(), timeout)
#     880 finally:
#     881     # request that overlapped reads stop
#     882     for ov in ov_list:
#
# File ~\anaconda3\lib\multiprocessing\connection.py:811, in _exhaustive_wait(handles, timeout)
#     809 ready = []
#     810 while L:
# --> 811     res = _winapi.WaitForMultipleObjects(L, False, timeout)
#     812     if res == WAIT_TIMEOUT:
#     813         break
#
# KeyboardInterrupt:

# %% [markdown]
# * 생성된 이미지 예시를 출력합니다.

# %%
from IPython.display import Image as Display

Display('./results/simple/28000.png')

# %% [markdown]
# * 다음의 코드를 이용하여 학습된 모델 파라미터를 저장할 수 있습니다.

# %%
# 모델 파라미터 저장
torch.save(simple_generator.state_dict(), "Simple_Generator_for_Face_Mask.pt")
torch.save(simple_discriminator.state_dict(), "Simple_Discriminator_for_Face_Mask.pt")
print("Model saved!")
# Out:
# Model saved!

# %% [markdown]
# * 학습된 모델 파라미터를 불러와 이미지 생성을 진행할 수 있습니다.

# %%
# 생성자(generator) 초기화
simple_generator = SimpleGenerator()
simple_generator.cuda()
simple_generator.load_state_dict(torch.load("Simple_Generator_for_Face_Mask.pt"))
simple_generator.eval()
# Out:
# SimpleGenerator(
#   (label_embed): Embedding(2, 2)
#   (model): Sequential(
#     (0): Linear(in_features=102, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Linear(in_features=128, out_features=256, bias=True)
#     (3): BatchNorm1d(256, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Linear(in_features=256, out_features=512, bias=True)
#     (6): BatchNorm1d(512, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Linear(in_features=512, out_features=1024, bias=True)
#     (9): BatchNorm1d(1024, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2, inplace=True)
#     (11): Linear(in_features=1024, out_features=2048, bias=True)
#     (12): BatchNorm1d(2048, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (13): LeakyReLU(negative_slope=0.2, inplace=True)
#     (14): Linear(in_features=2048, out_features=4096, bias=True)
#     (15): Tanh()
#   )
# )

# %% [markdown]
# * 마스크를 착용한 얼굴을 생성합니다.

# %%
from IPython.display import Image as Display

# 랜덤 노이즈(noise) 및 랜덤 레이블(label) 샘플링
z = torch.normal(mean=0, std=1, size=(100, latent_dim)).cuda()
generated_labels = torch.cuda.IntTensor(100).fill_(0)

# 이미지 생성
generated_imgs = simple_generator(z, generated_labels)

# 생성된 이미지 중에서 100개를 선택하여 10 X 10 격자 이미지에 출력
save_image(generated_imgs.data[:100], f'./results/simple/with_mask.png', nrow=10, normalize=True)

Display('./results/simple/with_mask.png')

# %% [markdown]
# * 마스크를 착용하지 않은 얼굴을 생성합니다.

# %%
from IPython.display import Image as Display

# 랜덤 노이즈(noise) 및 랜덤 레이블(label) 샘플링
z = torch.normal(mean=0, std=1, size=(100, latent_dim)).cuda()
generated_labels = torch.cuda.IntTensor(100).fill_(1)

# 이미지 생성
generated_imgs = simple_generator(z, generated_labels)

# 생성된 이미지 중에서 100개를 선택하여 10 X 10 격자 이미지에 출력
save_image(generated_imgs.data[:100], f'./results/simple/with_no_mask.png', nrow=10, normalize=True)

Display('./results/simple/with_no_mask.png')

# %% [markdown]
# #### <b>(알아보기) DCGAN 실습 - 모델 정의</b>
#
# * 논문 제목: [Deep Convolutional Generative Adversarial Networks](https://arxiv.org/abs/1511.06434) <b>(ICLR 2016)</b>
# * Convoluational Layer를 활용하여 이미지 생성에 높은 성능을 보이는 DCGAN 모델을 학습해 봅시다.
#     * 마스크 착용 여부를 선택하기 위해 <b>조건부(conditional) GAN</b>을 이용합니다.
#     * <b>Reference</b>: [Conditional Generative Adversarial Nets (2014)](https://arxiv.org/abs/1411.1784)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * 생성자(Generator) 및 판별자(Discriminator) 모델을 정의합니다.
#     * 생성자 클래스: DCGANGenerator
#     * 판별자 클래스: DCGANDiscriminator
# * 본 소스코드는 원본 논문에서 제안한 아키텍처와 유사한 아키텍처를 이용합니다.
# * <b>Reference</b>: [PyTorch DCGAN 예시 코드](https://github.com/eriklindernoren/PyTorch-GAN/blob/master/implementations/dcgan/dcgan.py)

# %%
latent_dim = 100
n_classes = 2


# 생성자(Generator) 클래스 정의
class DCGANGenerator(nn.Module):
    def __init__(self):
        super(DCGANGenerator, self).__init__()

        # 레이블 정보를 임베딩 차원으로 매핑하여 사용
        self.label_embed = nn.Embedding(n_classes, n_classes)

        self.init_size = 4 # 원본 크기보다 16배 작은 값으로 초기화
        self.layer1 = nn.Sequential(nn.Linear(latent_dim + n_classes, 512 * self.init_size * self.init_size)) # 초기 채널의 크기는 512 

        self.conv_blocks = nn.Sequential(
            nn.BatchNorm2d(512), # 채널의 크기와 동일
            nn.Upsample(scale_factor=2), # 너비와 높이 2배씩 증가
            nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1), # 너비와 높이 유지
            nn.BatchNorm2d(512, 0.8),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Upsample(scale_factor=2), # 너비와 높이 2배씩 증가
            nn.Conv2d(512, 256, kernel_size=3, stride=1, padding=1), # 너비와 높이 유지, 채널의 크기는 256으로
            nn.BatchNorm2d(256, 0.8),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Upsample(scale_factor=2), # 너비와 높이 2배씩 증가
            nn.Conv2d(256, 128, kernel_size=3, stride=1, padding=1), # 너비와 높이 유지, 채널의 크기는 128로
            nn.BatchNorm2d(128, 0.8),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Upsample(scale_factor=2), # 너비와 높이 2배씩 증가
            nn.Conv2d(128, 64, kernel_size=3, stride=1, padding=1), # 너비와 높이 유지, 채널의 크기는 64로
            nn.BatchNorm2d(64, 0.8),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(64, 1, kernel_size=3, stride=1, padding=1), # 너비와 높이 유지, 채널의 크기는 3으로
            nn.Tanh(),
        )

    def forward(self, noise, labels):
        # 노이즈(noise) 벡터와 레이블 임베딩을 순차적으로 연결하여 입력
        inputs = torch.cat((noise, self.label_embed(labels)), -1)
        output = self.layer1(inputs)
        output = output.view(output.size(0), 512, self.init_size, self.init_size)
        output = self.conv_blocks(output)
        return output


# 판별자(Discriminator) 클래스 정의
class DCGANDiscriminator(nn.Module):
    def __init__(self):
        super(DCGANDiscriminator, self).__init__()

        def make_block(in_channels, out_channels, bn=True):
            # 하나의 블록(block)을 반복할 때마다 너비와 높이는 2배씩 감소
            block = [nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=2, padding=1)]
            block.append(nn.LeakyReLU(0.2, inplace=True))
            block.append(nn.Dropout2d(0.25))
            if bn:
                block.append(nn.BatchNorm2d(out_channels, 0.8))
            return block

        # 너비와 높이가 32배씩 감소
        self.conv_blocks = nn.Sequential(
            *make_block(2, 32, bn=False),
            *make_block(32, 64),
            *make_block(64, 128),
            *make_block(128, 256),
            *make_block(256, 512),
        )

        self.classifier = nn.Sequential(
            nn.Linear(512 * 2 * 2, 1),
            nn.Sigmoid()
        )

        # 레이블 정보를 임베딩 차원으로 매핑하여 사용
        self.label_embed = nn.Embedding(n_classes, 1 * 64 * 64)

    # 이미지에 대한 판별 결과를 반환
    def forward(self, img, labels):
        # 이미지 벡터와 레이블 임베딩을 순차적으로 연결하여 입력
        embed = self.label_embed(labels).view((img.size(0), 1, 64, 64))
        inputs = torch.cat((img, embed), 1)
        output = self.conv_blocks(inputs)
        output = output.view(output.size(0), -1)
        output = self.classifier(output)
        return output

# %% [markdown]
# #### <b>(알아보기) DCGAN 실습 - 모델 학습 및 샘플링</b>
#
# * 학습을 위해 생성자와 판별자 모델을 초기화합니다.
# * 적절한 하이퍼 파라미터를 설정합니다.

# %%
def weights_init_normal(m):
    classname = m.__class__.__name__
    if classname.find("Conv") != -1:
        torch.nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find("BatchNorm2d") != -1:
        torch.nn.init.normal_(m.weight.data, 1.0, 0.02)
        torch.nn.init.constant_(m.bias.data, 0.0)


# 생성자(generator)와 판별자(discriminator) 초기화
dcgan_generator = DCGANGenerator()
dcgan_discriminator = DCGANDiscriminator()

dcgan_generator.cuda()
dcgan_discriminator.cuda()

# 가중치(weights) 초기화
dcgan_generator.apply(weights_init_normal)
dcgan_discriminator.apply(weights_init_normal)

# 손실 함수(loss function)
adversarial_loss = nn.MSELoss()
adversarial_loss.cuda()

# 학습률(learning rate) 설정
lr = 0.0001

# 생성자와 판별자를 위한 최적화 함수
optimizer_G = torch.optim.Adam(dcgan_generator.parameters(), lr=lr, betas=(0.5, 0.999))
optimizer_D = torch.optim.Adam(dcgan_discriminator.parameters(), lr=lr, betas=(0.5, 0.999))

# %% [markdown]
# * 모델을 학습하면서 주기적으로 샘플링하여 결과를 확인할 수 있습니다.

# %%
# !mkdir -p ./results/dcgan/

n_epochs = 400 # 학습의 횟수(epoch) 설정
sample_interval = 500 # 몇 번의 배치(batch)마다 결과를 출력할 것인지 설정
start_time = time.time()

for epoch in range(n_epochs):
    for i, (imgs, labels) in enumerate(train_dataloader):

        # 진짜(real) 이미지와 가짜(fake) 이미지에 대한 정답 레이블 생성
        real = torch.cuda.FloatTensor(imgs.shape[0], 1).fill_(1.0) # 진짜(real): 1
        fake = torch.cuda.FloatTensor(imgs.shape[0], 1).fill_(0.0) # 가짜(fake): 0

        real_imgs = imgs.cuda()
        labels = labels.cuda()

        """ 생성자(generator)를 학습합니다. """
        optimizer_G.zero_grad()

        # 랜덤 노이즈(noise) 및 랜덤 레이블(label) 샘플링
        z = torch.normal(mean=0, std=1, size=(imgs.shape[0], latent_dim)).cuda()
        generated_labels = torch.randint(0, n_classes, (imgs.shape[0],)).cuda()

        # 이미지 생성
        generated_imgs = dcgan_generator(z, generated_labels)

        # 생성자(generator)의 손실(loss) 값 계산
        g_loss = adversarial_loss(dcgan_discriminator(generated_imgs, generated_labels), real)

        # 생성자(generator) 업데이트
        g_loss.backward()
        optimizer_G.step()

        """ 판별자(discriminator)를 학습합니다. """
        optimizer_D.zero_grad()

        # 판별자(discriminator)의 손실(loss) 값 계산
        real_loss = adversarial_loss(dcgan_discriminator(real_imgs, labels), real)
        fake_loss = adversarial_loss(dcgan_discriminator(generated_imgs.detach(), generated_labels), fake)
        d_loss = (real_loss + fake_loss) / 2

        # 판별자(discriminator) 업데이트
        d_loss.backward()
        optimizer_D.step()

        done = epoch * len(train_dataloader) + i
        if done % sample_interval == 0:
            # 클래스당 8개의 이미지를 생성하여 2 X 8 격자 이미지에 출력
            z = torch.normal(mean=0, std=1, size=(n_classes * 8, latent_dim)).cuda()
            labels = torch.LongTensor([i for i in range(n_classes) for _ in range(8)]).cuda()
            generated_imgs = dcgan_generator(z, labels)
            save_image(generated_imgs, f"./results/dcgan/{done}.png", nrow=8, normalize=True)

    # 하나의 epoch이 끝날 때마다 로그(log) 출력
    print(f"[Epoch {epoch}/{n_epochs}] [D loss: {d_loss.item():.6f}] [G loss: {g_loss.item():.6f}] [Elapsed time: {time.time() - start_time:.2f}s]")
# Out:
# [Epoch 0/400] [D loss: 0.240555] [G loss: 0.282358] [Elapsed time: 27.07s]
# [Epoch 1/400] [D loss: 0.256578] [G loss: 0.242345] [Elapsed time: 54.33s]
# [Epoch 2/400] [D loss: 0.235582] [G loss: 0.248942] [Elapsed time: 81.22s]
# [Epoch 3/400] [D loss: 0.243892] [G loss: 0.239107] [Elapsed time: 108.06s]
# [Epoch 4/400] [D loss: 0.231488] [G loss: 0.270925] [Elapsed time: 134.59s]
# [Epoch 5/400] [D loss: 0.271561] [G loss: 0.224761] [Elapsed time: 160.65s]
# [Epoch 6/400] [D loss: 0.245657] [G loss: 0.263352] [Elapsed time: 186.84s]
# [Epoch 7/400] [D loss: 0.264052] [G loss: 0.246665] [Elapsed time: 212.96s]
# [Epoch 8/400] [D loss: 0.259749] [G loss: 0.244098] [Elapsed time: 239.00s]
# [Epoch 9/400] [D loss: 0.233481] [G loss: 0.293809] [Elapsed time: 265.15s]
# [Epoch 10/400] [D loss: 0.262262] [G loss: 0.253984] [Elapsed time: 291.21s]
# [Epoch 11/400] [D loss: 0.254901] [G loss: 0.281914] [Elapsed time: 317.61s]
# [Epoch 12/400] [D loss: 0.256762] [G loss: 0.229823] [Elapsed time: 343.86s]
# [Epoch 13/400] [D loss: 0.259358] [G loss: 0.237882] [Elapsed time: 371.13s]
# [Epoch 14/400] [D loss: 0.216037] [G loss: 0.216044] [Elapsed time: 397.98s]
# [Epoch 15/400] [D loss: 0.239875] [G loss: 0.279065] [Elapsed time: 424.26s]
# [Epoch 16/400] [D loss: 0.257414] [G loss: 0.243448] [Elapsed time: 451.53s]
# [Epoch 17/400] [D loss: 0.256846] [G loss: 0.275591] [Elapsed time: 477.97s]
# [Epoch 18/400] [D loss: 0.250917] [G loss: 0.270462] [Elapsed time: 504.55s]
# [Epoch 19/400] [D loss: 0.252770] [G loss: 0.214150] [Elapsed time: 530.89s]
# [Epoch 20/400] [D loss: 0.261625] [G loss: 0.338721] [Elapsed time: 557.39s]
# [Epoch 21/400] [D loss: 0.248072] [G loss: 0.254744] [Elapsed time: 583.64s]
# [Epoch 22/400] [D loss: 0.245191] [G loss: 0.251860] [Elapsed time: 610.02s]
# [Epoch 23/400] [D loss: 0.249273] [G loss: 0.270180] [Elapsed time: 636.50s]
# [Epoch 24/400] [D loss: 0.264866] [G loss: 0.228158] [Elapsed time: 662.99s]
# [Epoch 25/400] [D loss: 0.253271] [G loss: 0.205301] [Elapsed time: 689.51s]
# [Epoch 26/400] [D loss: 0.273905] [G loss: 0.245736] [Elapsed time: 716.01s]
# [Epoch 27/400] [D loss: 0.249237] [G loss: 0.268599] [Elapsed time: 742.15s]
# [Epoch 28/400] [D loss: 0.253003] [G loss: 0.236580] [Elapsed time: 768.36s]
# [Epoch 29/400] [D loss: 0.250343] [G loss: 0.241966] [Elapsed time: 794.64s]
# [Epoch 30/400] [D loss: 0.259552] [G loss: 0.256929] [Elapsed time: 820.83s]
# [Epoch 31/400] [D loss: 0.271966] [G loss: 0.248868] [Elapsed time: 846.96s]
# [Epoch 32/400] [D loss: 0.253047] [G loss: 0.239690] [Elapsed time: 873.09s]
# [Epoch 33/400] [D loss: 0.260298] [G loss: 0.232910] [Elapsed time: 899.34s]
# [Epoch 34/400] [D loss: 0.254137] [G loss: 0.252793] [Elapsed time: 925.80s]
# [Epoch 35/400] [D loss: 0.253833] [G loss: 0.223714] [Elapsed time: 952.51s]
# [Epoch 36/400] [D loss: 0.248401] [G loss: 0.262089] [Elapsed time: 978.80s]
# [Epoch 37/400] [D loss: 0.251476] [G loss: 0.226866] [Elapsed time: 1005.07s]
# [Epoch 38/400] [D loss: 0.256977] [G loss: 0.261245] [Elapsed time: 1031.47s]
# [Epoch 39/400] [D loss: 0.249494] [G loss: 0.253688] [Elapsed time: 1057.93s]
# [Epoch 40/400] [D loss: 0.247746] [G loss: 0.276703] [Elapsed time: 1084.53s]
# [Epoch 41/400] [D loss: 0.253593] [G loss: 0.237960] [Elapsed time: 1111.00s]
# [Epoch 42/400] [D loss: 0.249150] [G loss: 0.257129] [Elapsed time: 1137.33s]
# [Epoch 43/400] [D loss: 0.240313] [G loss: 0.251777] [Elapsed time: 1163.73s]
# [Epoch 44/400] [D loss: 0.253048] [G loss: 0.238154] [Elapsed time: 1190.20s]
# [Epoch 45/400] [D loss: 0.254837] [G loss: 0.263068] [Elapsed time: 1216.46s]
# [Epoch 46/400] [D loss: 0.260230] [G loss: 0.263833] [Elapsed time: 1242.67s]
# [Epoch 47/400] [D loss: 0.250320] [G loss: 0.244080] [Elapsed time: 1268.86s]
# [Epoch 48/400] [D loss: 0.247188] [G loss: 0.266829] [Elapsed time: 1295.14s]
# [Epoch 49/400] [D loss: 0.246368] [G loss: 0.242252] [Elapsed time: 1321.44s]
# [Epoch 50/400] [D loss: 0.248427] [G loss: 0.241540] [Elapsed time: 1347.60s]
# [Epoch 51/400] [D loss: 0.242581] [G loss: 0.225801] [Elapsed time: 1373.87s]
# [Epoch 52/400] [D loss: 0.242882] [G loss: 0.261632] [Elapsed time: 1400.04s]
# [Epoch 53/400] [D loss: 0.267888] [G loss: 0.252053] [Elapsed time: 1426.28s]
# [Epoch 54/400] [D loss: 0.257979] [G loss: 0.226541] [Elapsed time: 1452.94s]
# [Epoch 55/400] [D loss: 0.250718] [G loss: 0.259266] [Elapsed time: 1479.29s]
# [Epoch 56/400] [D loss: 0.236310] [G loss: 0.248452] [Elapsed time: 1505.67s]
# [Epoch 57/400] [D loss: 0.244792] [G loss: 0.278760] [Elapsed time: 1532.00s]
# [Epoch 58/400] [D loss: 0.247880] [G loss: 0.290919] [Elapsed time: 1558.42s]
# [Epoch 59/400] [D loss: 0.256211] [G loss: 0.268981] [Elapsed time: 1585.01s]
# [Epoch 60/400] [D loss: 0.247225] [G loss: 0.255162] [Elapsed time: 1611.21s]
# [Epoch 61/400] [D loss: 0.238626] [G loss: 0.305315] [Elapsed time: 1637.35s]
# [Epoch 62/400] [D loss: 0.243660] [G loss: 0.251502] [Elapsed time: 1663.59s]
# [Epoch 63/400] [D loss: 0.245790] [G loss: 0.273966] [Elapsed time: 1689.70s]
# [Epoch 64/400] [D loss: 0.258178] [G loss: 0.267041] [Elapsed time: 1715.80s]
# [Epoch 65/400] [D loss: 0.248644] [G loss: 0.236002] [Elapsed time: 1742.02s]
# [Epoch 66/400] [D loss: 0.255657] [G loss: 0.232913] [Elapsed time: 1768.44s]
# [Epoch 67/400] [D loss: 0.254563] [G loss: 0.253916] [Elapsed time: 1794.63s]
# [Epoch 68/400] [D loss: 0.254291] [G loss: 0.263120] [Elapsed time: 1820.82s]
# [Epoch 69/400] [D loss: 0.254734] [G loss: 0.281039] [Elapsed time: 1847.00s]
# [Epoch 70/400] [D loss: 0.247562] [G loss: 0.262905] [Elapsed time: 1873.12s]
# [Epoch 71/400] [D loss: 0.265909] [G loss: 0.231821] [Elapsed time: 1899.33s]
# [Epoch 72/400] [D loss: 0.241828] [G loss: 0.241280] [Elapsed time: 1925.54s]
# [Epoch 73/400] [D loss: 0.249296] [G loss: 0.256802] [Elapsed time: 1951.69s]
# [Epoch 74/400] [D loss: 0.251208] [G loss: 0.248869] [Elapsed time: 1977.89s]
# [Epoch 75/400] [D loss: 0.238701] [G loss: 0.272595] [Elapsed time: 2004.12s]
# [Epoch 76/400] [D loss: 0.245875] [G loss: 0.257296] [Elapsed time: 2030.10s]
# [Epoch 77/400] [D loss: 0.249177] [G loss: 0.249103] [Elapsed time: 2056.06s]
# [Epoch 78/400] [D loss: 0.251293] [G loss: 0.231211] [Elapsed time: 2082.06s]
# [Epoch 79/400] [D loss: 0.249478] [G loss: 0.286189] [Elapsed time: 2108.16s]
# [Epoch 80/400] [D loss: 0.235280] [G loss: 0.252925] [Elapsed time: 2134.31s]
# [Epoch 81/400] [D loss: 0.246568] [G loss: 0.228534] [Elapsed time: 2160.55s]
# [Epoch 82/400] [D loss: 0.241379] [G loss: 0.244579] [Elapsed time: 2186.95s]
# [Epoch 83/400] [D loss: 0.249548] [G loss: 0.239836] [Elapsed time: 2213.16s]
# [Epoch 84/400] [D loss: 0.238373] [G loss: 0.277351] [Elapsed time: 2239.17s]
# [Epoch 85/400] [D loss: 0.245868] [G loss: 0.254869] [Elapsed time: 2265.39s]
# [Epoch 86/400] [D loss: 0.248701] [G loss: 0.241833] [Elapsed time: 2291.59s]
# [Epoch 87/400] [D loss: 0.239914] [G loss: 0.238043] [Elapsed time: 2317.68s]
# [Epoch 88/400] [D loss: 0.242064] [G loss: 0.251377] [Elapsed time: 2343.90s]
# [Epoch 89/400] [D loss: 0.258909] [G loss: 0.266654] [Elapsed time: 2370.19s]
# [Epoch 90/400] [D loss: 0.253114] [G loss: 0.259557] [Elapsed time: 2396.55s]
# [Epoch 91/400] [D loss: 0.254796] [G loss: 0.265401] [Elapsed time: 2423.24s]
# [Epoch 92/400] [D loss: 0.239464] [G loss: 0.271271] [Elapsed time: 2450.73s]
# [Epoch 93/400] [D loss: 0.247849] [G loss: 0.290134] [Elapsed time: 2478.06s]
# [Epoch 94/400] [D loss: 0.254260] [G loss: 0.253262] [Elapsed time: 2505.08s]
# [Epoch 95/400] [D loss: 0.247592] [G loss: 0.243460] [Elapsed time: 2531.85s]
# [Epoch 96/400] [D loss: 0.237153] [G loss: 0.245357] [Elapsed time: 2557.95s]
# [Epoch 97/400] [D loss: 0.263102] [G loss: 0.218032] [Elapsed time: 2584.12s]
# [Epoch 98/400] [D loss: 0.250556] [G loss: 0.239584] [Elapsed time: 2610.14s]
# [Epoch 99/400] [D loss: 0.245198] [G loss: 0.245795] [Elapsed time: 2636.17s]
# [Epoch 100/400] [D loss: 0.250449] [G loss: 0.223175] [Elapsed time: 2662.20s]
# [Epoch 101/400] [D loss: 0.263853] [G loss: 0.224214] [Elapsed time: 2688.33s]
# [Epoch 102/400] [D loss: 0.235694] [G loss: 0.259301] [Elapsed time: 2714.47s]
# [Epoch 103/400] [D loss: 0.244255] [G loss: 0.245795] [Elapsed time: 2740.60s]
# [Epoch 104/400] [D loss: 0.244291] [G loss: 0.238121] [Elapsed time: 2766.59s]
# [Epoch 105/400] [D loss: 0.248690] [G loss: 0.277155] [Elapsed time: 2792.55s]
# [Epoch 106/400] [D loss: 0.246752] [G loss: 0.249237] [Elapsed time: 2818.65s]
# [Epoch 107/400] [D loss: 0.266659] [G loss: 0.232217] [Elapsed time: 2845.22s]
# [Epoch 108/400] [D loss: 0.254741] [G loss: 0.279208] [Elapsed time: 2871.45s]
# [Epoch 109/400] [D loss: 0.234002] [G loss: 0.257707] [Elapsed time: 2897.59s]
# [Epoch 110/400] [D loss: 0.244578] [G loss: 0.228952] [Elapsed time: 2924.14s]
# [Epoch 111/400] [D loss: 0.260397] [G loss: 0.242111] [Elapsed time: 2950.58s]
# [Epoch 112/400] [D loss: 0.224572] [G loss: 0.278991] [Elapsed time: 2976.66s]
# [Epoch 113/400] [D loss: 0.245481] [G loss: 0.280836] [Elapsed time: 3002.89s]
# [Epoch 114/400] [D loss: 0.230831] [G loss: 0.265526] [Elapsed time: 3029.07s]
# [Epoch 115/400] [D loss: 0.238942] [G loss: 0.306626] [Elapsed time: 3055.11s]
# [Epoch 116/400] [D loss: 0.265188] [G loss: 0.274841] [Elapsed time: 3081.76s]
# [Epoch 117/400] [D loss: 0.236670] [G loss: 0.241580] [Elapsed time: 3108.77s]
# [Epoch 118/400] [D loss: 0.255728] [G loss: 0.272146] [Elapsed time: 3135.46s]
# [Epoch 119/400] [D loss: 0.244207] [G loss: 0.253971] [Elapsed time: 3161.73s]
# [Epoch 120/400] [D loss: 0.228977] [G loss: 0.302926] [Elapsed time: 3188.25s]
# [Epoch 121/400] [D loss: 0.253250] [G loss: 0.263127] [Elapsed time: 3214.94s]
# [Epoch 122/400] [D loss: 0.251661] [G loss: 0.211810] [Elapsed time: 3241.86s]
# [Epoch 123/400] [D loss: 0.248645] [G loss: 0.246536] [Elapsed time: 3268.48s]
# [Epoch 124/400] [D loss: 0.263168] [G loss: 0.272077] [Elapsed time: 3295.03s]
# [Epoch 125/400] [D loss: 0.245346] [G loss: 0.283390] [Elapsed time: 3321.57s]
# [Epoch 126/400] [D loss: 0.244370] [G loss: 0.249125] [Elapsed time: 3348.02s]
# [Epoch 127/400] [D loss: 0.265692] [G loss: 0.264301] [Elapsed time: 3374.78s]
# [Epoch 128/400] [D loss: 0.261248] [G loss: 0.203648] [Elapsed time: 3400.86s]
# [Epoch 129/400] [D loss: 0.249280] [G loss: 0.258493] [Elapsed time: 3427.10s]
# [Epoch 130/400] [D loss: 0.237649] [G loss: 0.225328] [Elapsed time: 3453.39s]
# [Epoch 131/400] [D loss: 0.246440] [G loss: 0.236226] [Elapsed time: 3479.78s]
# [Epoch 132/400] [D loss: 0.268708] [G loss: 0.291250] [Elapsed time: 3506.27s]
# [Epoch 133/400] [D loss: 0.268998] [G loss: 0.237331] [Elapsed time: 3532.73s]
# [Epoch 134/400] [D loss: 0.246522] [G loss: 0.285823] [Elapsed time: 3559.96s]
# [Epoch 135/400] [D loss: 0.223591] [G loss: 0.267523] [Elapsed time: 3586.35s]
# [Epoch 136/400] [D loss: 0.233340] [G loss: 0.286533] [Elapsed time: 3613.16s]
# [Epoch 137/400] [D loss: 0.245267] [G loss: 0.234604] [Elapsed time: 3639.68s]
# [Epoch 138/400] [D loss: 0.222911] [G loss: 0.225157] [Elapsed time: 3665.96s]
# [Epoch 139/400] [D loss: 0.239865] [G loss: 0.231881] [Elapsed time: 3692.60s]
# [Epoch 140/400] [D loss: 0.220565] [G loss: 0.253414] [Elapsed time: 3719.12s]
# [Epoch 141/400] [D loss: 0.262673] [G loss: 0.265622] [Elapsed time: 3746.17s]
# [Epoch 142/400] [D loss: 0.230195] [G loss: 0.279264] [Elapsed time: 3773.01s]
# [Epoch 143/400] [D loss: 0.226754] [G loss: 0.264131] [Elapsed time: 3799.52s]
# [Epoch 144/400] [D loss: 0.259909] [G loss: 0.287908] [Elapsed time: 3825.97s]
# [Epoch 145/400] [D loss: 0.248481] [G loss: 0.272044] [Elapsed time: 3852.44s]
# [Epoch 146/400] [D loss: 0.221904] [G loss: 0.322202] [Elapsed time: 3879.06s]
# [Epoch 147/400] [D loss: 0.255528] [G loss: 0.257665] [Elapsed time: 3905.22s]
# [Epoch 148/400] [D loss: 0.217023] [G loss: 0.265693] [Elapsed time: 3931.15s]
# [Epoch 149/400] [D loss: 0.269744] [G loss: 0.240935] [Elapsed time: 3957.51s]
# [Epoch 150/400] [D loss: 0.275572] [G loss: 0.205840] [Elapsed time: 3983.74s]
# [Epoch 151/400] [D loss: 0.228883] [G loss: 0.237894] [Elapsed time: 4009.95s]
# [Epoch 152/400] [D loss: 0.280667] [G loss: 0.240771] [Elapsed time: 4036.25s]
# [Epoch 153/400] [D loss: 0.251255] [G loss: 0.309355] [Elapsed time: 4062.49s]
# [Epoch 154/400] [D loss: 0.239868] [G loss: 0.228108] [Elapsed time: 4088.89s]
# [Epoch 155/400] [D loss: 0.242355] [G loss: 0.214152] [Elapsed time: 4115.49s]
# [Epoch 156/400] [D loss: 0.261947] [G loss: 0.186880] [Elapsed time: 4141.92s]
# [Epoch 157/400] [D loss: 0.195905] [G loss: 0.276034] [Elapsed time: 4168.10s]
# [Epoch 158/400] [D loss: 0.222203] [G loss: 0.285715] [Elapsed time: 4194.07s]
# [Epoch 159/400] [D loss: 0.266086] [G loss: 0.283375] [Elapsed time: 4220.07s]
# [Epoch 160/400] [D loss: 0.213878] [G loss: 0.274115] [Elapsed time: 4246.57s]
# [Epoch 161/400] [D loss: 0.261206] [G loss: 0.251649] [Elapsed time: 4272.70s]
# [Epoch 162/400] [D loss: 0.286284] [G loss: 0.227351] [Elapsed time: 4298.94s]
# [Epoch 163/400] [D loss: 0.190016] [G loss: 0.296303] [Elapsed time: 4325.36s]
# [Epoch 164/400] [D loss: 0.270988] [G loss: 0.282697] [Elapsed time: 4351.85s]
# [Epoch 165/400] [D loss: 0.260008] [G loss: 0.246298] [Elapsed time: 4377.97s]
# [Epoch 166/400] [D loss: 0.215554] [G loss: 0.379436] [Elapsed time: 4404.33s]
# [Epoch 167/400] [D loss: 0.244933] [G loss: 0.187443] [Elapsed time: 4430.70s]
# [Epoch 168/400] [D loss: 0.238435] [G loss: 0.327638] [Elapsed time: 4457.11s]
# [Epoch 169/400] [D loss: 0.203557] [G loss: 0.180167] [Elapsed time: 4483.39s]
# [Epoch 170/400] [D loss: 0.243520] [G loss: 0.328432] [Elapsed time: 4509.77s]
# [Epoch 171/400] [D loss: 0.232588] [G loss: 0.255459] [Elapsed time: 4536.16s]
# [Epoch 172/400] [D loss: 0.213546] [G loss: 0.276595] [Elapsed time: 4562.87s]
# [Epoch 173/400] [D loss: 0.248285] [G loss: 0.319932] [Elapsed time: 4590.28s]
# [Epoch 174/400] [D loss: 0.251017] [G loss: 0.323687] [Elapsed time: 4616.67s]
# [Epoch 175/400] [D loss: 0.258676] [G loss: 0.269588] [Elapsed time: 4643.11s]
# [Epoch 176/400] [D loss: 0.246103] [G loss: 0.160803] [Elapsed time: 4669.46s]
# [Epoch 177/400] [D loss: 0.241043] [G loss: 0.281691] [Elapsed time: 4695.92s]
# [Epoch 178/400] [D loss: 0.136853] [G loss: 0.363988] [Elapsed time: 4723.19s]
# [Epoch 179/400] [D loss: 0.273303] [G loss: 0.290138] [Elapsed time: 4750.74s]
# [Epoch 180/400] [D loss: 0.178765] [G loss: 0.348473] [Elapsed time: 4777.63s]
# [Epoch 181/400] [D loss: 0.200700] [G loss: 0.380884] [Elapsed time: 4805.30s]
# [Epoch 182/400] [D loss: 0.283189] [G loss: 0.257354] [Elapsed time: 4832.24s]
# [Epoch 183/400] [D loss: 0.231070] [G loss: 0.223057] [Elapsed time: 4860.14s]
# [Epoch 184/400] [D loss: 0.246775] [G loss: 0.306655] [Elapsed time: 4887.96s]
# [Epoch 185/400] [D loss: 0.251774] [G loss: 0.332512] [Elapsed time: 4915.66s]
# [Epoch 186/400] [D loss: 0.224526] [G loss: 0.310211] [Elapsed time: 4943.26s]
# [Epoch 187/400] [D loss: 0.205953] [G loss: 0.318771] [Elapsed time: 4971.02s]
# [Epoch 188/400] [D loss: 0.242521] [G loss: 0.320689] [Elapsed time: 4998.65s]
# [Epoch 189/400] [D loss: 0.189291] [G loss: 0.368769] [Elapsed time: 5026.17s]
# [Epoch 190/400] [D loss: 0.247583] [G loss: 0.361596] [Elapsed time: 5053.68s]
# [Epoch 191/400] [D loss: 0.236654] [G loss: 0.265603] [Elapsed time: 5081.45s]
# [Epoch 192/400] [D loss: 0.272174] [G loss: 0.262455] [Elapsed time: 5109.15s]
# [Epoch 193/400] [D loss: 0.225164] [G loss: 0.294816] [Elapsed time: 5135.56s]
# [Epoch 194/400] [D loss: 0.292512] [G loss: 0.276377] [Elapsed time: 5161.80s]
# [Epoch 195/400] [D loss: 0.184513] [G loss: 0.392148] [Elapsed time: 5188.46s]
# [Epoch 196/400] [D loss: 0.232600] [G loss: 0.321305] [Elapsed time: 5214.83s]
# [Epoch 197/400] [D loss: 0.251507] [G loss: 0.256322] [Elapsed time: 5241.33s]
# [Epoch 198/400] [D loss: 0.202359] [G loss: 0.296683] [Elapsed time: 5268.16s]
# [Epoch 199/400] [D loss: 0.222020] [G loss: 0.290478] [Elapsed time: 5294.59s]
# [Epoch 200/400] [D loss: 0.224242] [G loss: 0.426819] [Elapsed time: 5321.21s]
# [Epoch 201/400] [D loss: 0.213013] [G loss: 0.273714] [Elapsed time: 5347.90s]
# [Epoch 202/400] [D loss: 0.213260] [G loss: 0.308164] [Elapsed time: 5374.84s]
# [Epoch 203/400] [D loss: 0.228306] [G loss: 0.204603] [Elapsed time: 5400.93s]
# [Epoch 204/400] [D loss: 0.212860] [G loss: 0.398705] [Elapsed time: 5427.01s]
# [Epoch 205/400] [D loss: 0.196316] [G loss: 0.371810] [Elapsed time: 5453.47s]
# [Epoch 206/400] [D loss: 0.221232] [G loss: 0.344470] [Elapsed time: 5479.42s]
# [Epoch 207/400] [D loss: 0.222963] [G loss: 0.310892] [Elapsed time: 5505.62s]
# [Epoch 208/400] [D loss: 0.229774] [G loss: 0.305416] [Elapsed time: 5531.81s]
# [Epoch 209/400] [D loss: 0.265833] [G loss: 0.329114] [Elapsed time: 5558.15s]
# [Epoch 210/400] [D loss: 0.159939] [G loss: 0.280491] [Elapsed time: 5584.59s]
# [Epoch 211/400] [D loss: 0.276281] [G loss: 0.309851] [Elapsed time: 5610.93s]
# [Epoch 212/400] [D loss: 0.252820] [G loss: 0.307835] [Elapsed time: 5637.57s]
# [Epoch 213/400] [D loss: 0.233064] [G loss: 0.322686] [Elapsed time: 5664.06s]
# [Epoch 214/400] [D loss: 0.231579] [G loss: 0.425125] [Elapsed time: 5690.46s]
# [Epoch 215/400] [D loss: 0.225535] [G loss: 0.312261] [Elapsed time: 5716.35s]
# [Epoch 216/400] [D loss: 0.208608] [G loss: 0.261728] [Elapsed time: 5742.32s]
# [Epoch 217/400] [D loss: 0.234454] [G loss: 0.148630] [Elapsed time: 5768.28s]
# [Epoch 218/400] [D loss: 0.217764] [G loss: 0.309256] [Elapsed time: 5794.29s]
# [Epoch 219/400] [D loss: 0.287794] [G loss: 0.351324] [Elapsed time: 5820.26s]
# [Epoch 220/400] [D loss: 0.218347] [G loss: 0.258804] [Elapsed time: 5846.22s]
# [Epoch 221/400] [D loss: 0.254563] [G loss: 0.270456] [Elapsed time: 5872.11s]
# [Epoch 222/400] [D loss: 0.235715] [G loss: 0.202201] [Elapsed time: 5898.04s]
# [Epoch 223/400] [D loss: 0.238678] [G loss: 0.309941] [Elapsed time: 5924.02s]
# [Epoch 224/400] [D loss: 0.248698] [G loss: 0.240295] [Elapsed time: 5950.12s]
# [Epoch 225/400] [D loss: 0.246031] [G loss: 0.249020] [Elapsed time: 5976.07s]
# [Epoch 226/400] [D loss: 0.261049] [G loss: 0.273965] [Elapsed time: 6002.12s]
# [Epoch 227/400] [D loss: 0.308002] [G loss: 0.351944] [Elapsed time: 6029.42s]
# [Epoch 228/400] [D loss: 0.214856] [G loss: 0.280049] [Elapsed time: 6057.11s]
# [Epoch 229/400] [D loss: 0.265817] [G loss: 0.248931] [Elapsed time: 6083.45s]
# [Epoch 230/400] [D loss: 0.316110] [G loss: 0.213075] [Elapsed time: 6109.52s]
# [Epoch 231/400] [D loss: 0.194107] [G loss: 0.146241] [Elapsed time: 6135.86s]
# [Epoch 232/400] [D loss: 0.137895] [G loss: 0.325481] [Elapsed time: 6162.56s]
# [Epoch 233/400] [D loss: 0.230065] [G loss: 0.196284] [Elapsed time: 6189.02s]
# [Epoch 234/400] [D loss: 0.276325] [G loss: 0.301477] [Elapsed time: 6215.12s]
# [Epoch 235/400] [D loss: 0.140803] [G loss: 0.303043] [Elapsed time: 6241.11s]
# [Epoch 236/400] [D loss: 0.211796] [G loss: 0.136509] [Elapsed time: 6267.66s]
# [Epoch 237/400] [D loss: 0.251454] [G loss: 0.225932] [Elapsed time: 6294.18s]
# [Epoch 238/400] [D loss: 0.288179] [G loss: 0.351051] [Elapsed time: 6320.83s]
# [Epoch 239/400] [D loss: 0.174564] [G loss: 0.379848] [Elapsed time: 6347.03s]
# [Epoch 240/400] [D loss: 0.176460] [G loss: 0.327576] [Elapsed time: 6373.53s]
# [Epoch 241/400] [D loss: 0.113622] [G loss: 0.329750] [Elapsed time: 6399.60s]
# [Epoch 242/400] [D loss: 0.181428] [G loss: 0.415258] [Elapsed time: 6426.03s]
# [Epoch 243/400] [D loss: 0.169650] [G loss: 0.204251] [Elapsed time: 6452.51s]
# [Epoch 244/400] [D loss: 0.210228] [G loss: 0.262571] [Elapsed time: 6478.69s]
# [Epoch 245/400] [D loss: 0.147134] [G loss: 0.143688] [Elapsed time: 6504.80s]
# [Epoch 246/400] [D loss: 0.245006] [G loss: 0.398294] [Elapsed time: 6530.87s]
# [Epoch 247/400] [D loss: 0.179378] [G loss: 0.229877] [Elapsed time: 6556.67s]
# [Epoch 248/400] [D loss: 0.148213] [G loss: 0.352049] [Elapsed time: 6582.70s]
# [Epoch 249/400] [D loss: 0.263672] [G loss: 0.345730] [Elapsed time: 6608.73s]
# [Epoch 250/400] [D loss: 0.291991] [G loss: 0.460264] [Elapsed time: 6634.70s]
# [Epoch 251/400] [D loss: 0.180774] [G loss: 0.474064] [Elapsed time: 6660.96s]
# [Epoch 252/400] [D loss: 0.248518] [G loss: 0.452090] [Elapsed time: 6687.09s]
# [Epoch 253/400] [D loss: 0.244985] [G loss: 0.309783] [Elapsed time: 6713.12s]
# [Epoch 254/400] [D loss: 0.138490] [G loss: 0.273630] [Elapsed time: 6739.26s]
# [Epoch 255/400] [D loss: 0.156082] [G loss: 0.348314] [Elapsed time: 6765.33s]
# [Epoch 256/400] [D loss: 0.194822] [G loss: 0.326919] [Elapsed time: 6791.30s]
# [Epoch 257/400] [D loss: 0.274741] [G loss: 0.315275] [Elapsed time: 6817.65s]
# [Epoch 258/400] [D loss: 0.300241] [G loss: 0.229406] [Elapsed time: 6843.83s]
# [Epoch 259/400] [D loss: 0.165064] [G loss: 0.365862] [Elapsed time: 6869.89s]
# [Epoch 260/400] [D loss: 0.261997] [G loss: 0.382205] [Elapsed time: 6895.94s]
# [Epoch 261/400] [D loss: 0.268057] [G loss: 0.473214] [Elapsed time: 6921.94s]
# [Epoch 262/400] [D loss: 0.193451] [G loss: 0.379897] [Elapsed time: 6947.90s]
# [Epoch 263/400] [D loss: 0.198441] [G loss: 0.418720] [Elapsed time: 6973.89s]
# [Epoch 264/400] [D loss: 0.085153] [G loss: 0.458508] [Elapsed time: 6999.94s]
# [Epoch 265/400] [D loss: 0.180817] [G loss: 0.478511] [Elapsed time: 7025.91s]
# [Epoch 266/400] [D loss: 0.205317] [G loss: 0.420300] [Elapsed time: 7051.88s]
# [Epoch 267/400] [D loss: 0.172013] [G loss: 0.237544] [Elapsed time: 7078.27s]
# [Epoch 268/400] [D loss: 0.209774] [G loss: 0.403387] [Elapsed time: 7104.23s]
# [Epoch 269/400] [D loss: 0.230724] [G loss: 0.275884] [Elapsed time: 7130.22s]
# [Epoch 270/400] [D loss: 0.284218] [G loss: 0.364064] [Elapsed time: 7156.85s]
# [Epoch 271/400] [D loss: 0.149600] [G loss: 0.405570] [Elapsed time: 7183.64s]
# [Epoch 272/400] [D loss: 0.194574] [G loss: 0.446928] [Elapsed time: 7210.05s]
# [Epoch 273/400] [D loss: 0.128525] [G loss: 0.403250] [Elapsed time: 7236.21s]
# [Epoch 274/400] [D loss: 0.080321] [G loss: 0.539812] [Elapsed time: 7262.65s]
# [Epoch 275/400] [D loss: 0.287084] [G loss: 0.389781] [Elapsed time: 7289.46s]
# [Epoch 276/400] [D loss: 0.217304] [G loss: 0.375669] [Elapsed time: 7316.25s]
# [Epoch 277/400] [D loss: 0.296313] [G loss: 0.389234] [Elapsed time: 7342.18s]
# [Epoch 278/400] [D loss: 0.197977] [G loss: 0.300633] [Elapsed time: 7368.16s]
# [Epoch 279/400] [D loss: 0.195215] [G loss: 0.303383] [Elapsed time: 7394.24s]
# [Epoch 280/400] [D loss: 0.297911] [G loss: 0.362659] [Elapsed time: 7420.79s]
# [Epoch 281/400] [D loss: 0.274689] [G loss: 0.419504] [Elapsed time: 7447.17s]
# [Epoch 282/400] [D loss: 0.123936] [G loss: 0.456114] [Elapsed time: 7473.38s]
# [Epoch 283/400] [D loss: 0.241442] [G loss: 0.559171] [Elapsed time: 7499.59s]
# [Epoch 284/400] [D loss: 0.249116] [G loss: 0.301515] [Elapsed time: 7525.56s]
# [Epoch 285/400] [D loss: 0.234309] [G loss: 0.253186] [Elapsed time: 7551.76s]
# [Epoch 286/400] [D loss: 0.165626] [G loss: 0.351246] [Elapsed time: 7577.83s]
# [Epoch 287/400] [D loss: 0.185614] [G loss: 0.499789] [Elapsed time: 7604.03s]
# [Epoch 288/400] [D loss: 0.230014] [G loss: 0.640418] [Elapsed time: 7630.20s]
# [Epoch 289/400] [D loss: 0.212519] [G loss: 0.479784] [Elapsed time: 7656.79s]
# [Epoch 290/400] [D loss: 0.278282] [G loss: 0.591017] [Elapsed time: 7683.32s]
# [Epoch 291/400] [D loss: 0.188057] [G loss: 0.346334] [Elapsed time: 7709.84s]
# [Epoch 292/400] [D loss: 0.222820] [G loss: 0.394861] [Elapsed time: 7736.29s]
# [Epoch 293/400] [D loss: 0.440789] [G loss: 0.464374] [Elapsed time: 7762.66s]
# [Epoch 294/400] [D loss: 0.256502] [G loss: 0.397893] [Elapsed time: 7789.19s]
# [Epoch 295/400] [D loss: 0.130414] [G loss: 0.417302] [Elapsed time: 7815.27s]
# [Epoch 296/400] [D loss: 0.173193] [G loss: 0.364470] [Elapsed time: 7841.28s]
# [Epoch 297/400] [D loss: 0.176207] [G loss: 0.254171] [Elapsed time: 7867.30s]
# [Epoch 298/400] [D loss: 0.224106] [G loss: 0.369851] [Elapsed time: 7893.76s]
# [Epoch 299/400] [D loss: 0.223591] [G loss: 0.272047] [Elapsed time: 7920.19s]
# [Epoch 300/400] [D loss: 0.189322] [G loss: 0.328912] [Elapsed time: 7946.45s]
# [Epoch 301/400] [D loss: 0.244903] [G loss: 0.480789] [Elapsed time: 7972.69s]
# [Epoch 302/400] [D loss: 0.399389] [G loss: 0.668579] [Elapsed time: 7998.84s]
# [Epoch 303/400] [D loss: 0.072423] [G loss: 0.493054] [Elapsed time: 8025.40s]
# [Epoch 304/400] [D loss: 0.181753] [G loss: 0.303590] [Elapsed time: 8051.36s]
# [Epoch 305/400] [D loss: 0.143743] [G loss: 0.404904] [Elapsed time: 8077.66s]
# [Epoch 306/400] [D loss: 0.145395] [G loss: 0.624019] [Elapsed time: 8104.01s]
# [Epoch 307/400] [D loss: 0.206048] [G loss: 0.648479] [Elapsed time: 8132.12s]
# [Epoch 308/400] [D loss: 0.144436] [G loss: 0.354494] [Elapsed time: 8158.89s]
# [Epoch 309/400] [D loss: 0.092168] [G loss: 0.496179] [Elapsed time: 8185.14s]
# [Epoch 310/400] [D loss: 0.114312] [G loss: 0.464976] [Elapsed time: 8211.12s]
# [Epoch 311/400] [D loss: 0.240016] [G loss: 0.448157] [Elapsed time: 8237.54s]
# [Epoch 312/400] [D loss: 0.158999] [G loss: 0.592035] [Elapsed time: 8264.33s]
# [Epoch 313/400] [D loss: 0.245324] [G loss: 0.497315] [Elapsed time: 8294.41s]
# [Epoch 314/400] [D loss: 0.088759] [G loss: 0.428403] [Elapsed time: 8320.83s]
# [Epoch 315/400] [D loss: 0.206789] [G loss: 0.280506] [Elapsed time: 8347.34s]
# [Epoch 316/400] [D loss: 0.103008] [G loss: 0.493551] [Elapsed time: 8374.13s]
# [Epoch 317/400] [D loss: 0.168494] [G loss: 0.732251] [Elapsed time: 8400.33s]
# [Epoch 318/400] [D loss: 0.209290] [G loss: 0.267560] [Elapsed time: 8426.48s]
# [Epoch 319/400] [D loss: 0.296814] [G loss: 0.358636] [Elapsed time: 8452.58s]
# [Epoch 320/400] [D loss: 0.239645] [G loss: 0.481158] [Elapsed time: 8478.63s]
# [Epoch 321/400] [D loss: 0.141918] [G loss: 0.476954] [Elapsed time: 8504.83s]
# [Epoch 322/400] [D loss: 0.130632] [G loss: 0.422660] [Elapsed time: 8531.26s]
# [Epoch 323/400] [D loss: 0.148811] [G loss: 0.518530] [Elapsed time: 8558.07s]
# [Epoch 324/400] [D loss: 0.313276] [G loss: 0.438355] [Elapsed time: 8584.76s]
# [Epoch 325/400] [D loss: 0.268124] [G loss: 0.385307] [Elapsed time: 8611.57s]
# [Epoch 326/400] [D loss: 0.246331] [G loss: 0.478903] [Elapsed time: 8638.34s]
# [Epoch 327/400] [D loss: 0.287286] [G loss: 0.286195] [Elapsed time: 8664.85s]
# [Epoch 328/400] [D loss: 0.191496] [G loss: 0.406675] [Elapsed time: 8691.41s]
# [Epoch 329/400] [D loss: 0.263919] [G loss: 0.768932] [Elapsed time: 8717.93s]
# [Epoch 330/400] [D loss: 0.176196] [G loss: 0.685472] [Elapsed time: 8744.31s]
# [Epoch 331/400] [D loss: 0.127062] [G loss: 0.116109] [Elapsed time: 8770.89s]
# [Epoch 332/400] [D loss: 0.195516] [G loss: 0.429504] [Elapsed time: 8797.56s]
# [Epoch 333/400] [D loss: 0.172464] [G loss: 0.674706] [Elapsed time: 8823.86s]
# [Epoch 334/400] [D loss: 0.241657] [G loss: 0.701980] [Elapsed time: 8850.00s]
# [Epoch 335/400] [D loss: 0.220624] [G loss: 0.560796] [Elapsed time: 8876.23s]
# [Epoch 336/400] [D loss: 0.309813] [G loss: 0.226474] [Elapsed time: 8902.56s]
# [Epoch 337/400] [D loss: 0.136268] [G loss: 0.558032] [Elapsed time: 8928.72s]
# [Epoch 338/400] [D loss: 0.300627] [G loss: 0.317743] [Elapsed time: 8954.82s]
# [Epoch 339/400] [D loss: 0.154649] [G loss: 0.229635] [Elapsed time: 8981.17s]
# [Epoch 340/400] [D loss: 0.127599] [G loss: 0.550392] [Elapsed time: 9007.57s]
# [Epoch 341/400] [D loss: 0.151633] [G loss: 0.599109] [Elapsed time: 9033.70s]
# [Epoch 342/400] [D loss: 0.181992] [G loss: 0.330355] [Elapsed time: 9059.73s]
# [Epoch 343/400] [D loss: 0.130473] [G loss: 0.429357] [Elapsed time: 9086.07s]
# [Epoch 344/400] [D loss: 0.189862] [G loss: 0.695553] [Elapsed time: 9112.17s]
# [Epoch 345/400] [D loss: 0.184068] [G loss: 0.474640] [Elapsed time: 9138.39s]
# [Epoch 346/400] [D loss: 0.134752] [G loss: 0.462972] [Elapsed time: 9164.45s]
# [Epoch 347/400] [D loss: 0.382565] [G loss: 0.318229] [Elapsed time: 9190.64s]
# [Epoch 348/400] [D loss: 0.251684] [G loss: 0.474803] [Elapsed time: 9216.61s]
# [Epoch 349/400] [D loss: 0.254463] [G loss: 0.505326] [Elapsed time: 9243.32s]
# [Epoch 350/400] [D loss: 0.074403] [G loss: 0.533820] [Elapsed time: 9269.46s]
# [Epoch 351/400] [D loss: 0.230958] [G loss: 0.338997] [Elapsed time: 9295.41s]
# [Epoch 352/400] [D loss: 0.101226] [G loss: 0.616670] [Elapsed time: 9322.00s]
# [Epoch 353/400] [D loss: 0.182076] [G loss: 0.211832] [Elapsed time: 9348.02s]
# [Epoch 354/400] [D loss: 0.127624] [G loss: 0.305210] [Elapsed time: 9375.01s]
# [Epoch 355/400] [D loss: 0.121434] [G loss: 0.682925] [Elapsed time: 9401.46s]
# [Epoch 356/400] [D loss: 0.232787] [G loss: 0.480977] [Elapsed time: 9427.98s]
# [Epoch 357/400] [D loss: 0.313545] [G loss: 0.675233] [Elapsed time: 9454.09s]
# [Epoch 358/400] [D loss: 0.138912] [G loss: 0.415352] [Elapsed time: 9480.31s]
# [Epoch 359/400] [D loss: 0.327005] [G loss: 0.425697] [Elapsed time: 9506.94s]
# [Epoch 360/400] [D loss: 0.119188] [G loss: 0.661107] [Elapsed time: 9533.25s]
# [Epoch 361/400] [D loss: 0.424394] [G loss: 0.398264] [Elapsed time: 9559.41s]
# [Epoch 362/400] [D loss: 0.178131] [G loss: 0.729647] [Elapsed time: 9585.55s]
# [Epoch 363/400] [D loss: 0.199637] [G loss: 0.388007] [Elapsed time: 9611.82s]
# [Epoch 364/400] [D loss: 0.067664] [G loss: 0.723556] [Elapsed time: 9638.16s]
# [Epoch 365/400] [D loss: 0.169249] [G loss: 0.638916] [Elapsed time: 9664.25s]
# [Epoch 366/400] [D loss: 0.223900] [G loss: 0.600204] [Elapsed time: 9690.59s]
# [Epoch 367/400] [D loss: 0.196727] [G loss: 0.622037] [Elapsed time: 9717.31s]
# [Epoch 368/400] [D loss: 0.130975] [G loss: 0.629359] [Elapsed time: 9744.01s]
# [Epoch 369/400] [D loss: 0.154635] [G loss: 0.603334] [Elapsed time: 9770.19s]
# [Epoch 370/400] [D loss: 0.214215] [G loss: 0.850233] [Elapsed time: 9796.61s]
# [Epoch 371/400] [D loss: 0.421305] [G loss: 0.498902] [Elapsed time: 9822.85s]
# [Epoch 372/400] [D loss: 0.097531] [G loss: 0.803599] [Elapsed time: 9848.79s]
# [Epoch 373/400] [D loss: 0.067982] [G loss: 0.591857] [Elapsed time: 9874.90s]
# [Epoch 374/400] [D loss: 0.202347] [G loss: 0.379951] [Elapsed time: 9900.81s]
# [Epoch 375/400] [D loss: 0.091373] [G loss: 0.612157] [Elapsed time: 9926.87s]
# [Epoch 376/400] [D loss: 0.081500] [G loss: 0.389850] [Elapsed time: 9953.03s]
# [Epoch 377/400] [D loss: 0.115211] [G loss: 0.675562] [Elapsed time: 9979.62s]
# [Epoch 378/400] [D loss: 0.245340] [G loss: 0.596954] [Elapsed time: 10005.69s]
# [Epoch 379/400] [D loss: 0.040502] [G loss: 0.575301] [Elapsed time: 10031.76s]
# [Epoch 380/400] [D loss: 0.098110] [G loss: 0.389256] [Elapsed time: 10057.77s]
# [Epoch 381/400] [D loss: 0.257478] [G loss: 0.322448] [Elapsed time: 10083.93s]
# [Epoch 382/400] [D loss: 0.261548] [G loss: 0.626834] [Elapsed time: 10110.13s]
# [Epoch 383/400] [D loss: 0.256959] [G loss: 0.792662] [Elapsed time: 10136.45s]
# [Epoch 384/400] [D loss: 0.093984] [G loss: 0.686252] [Elapsed time: 10162.74s]
# [Epoch 385/400] [D loss: 0.277192] [G loss: 0.513929] [Elapsed time: 10188.95s]
# [Epoch 386/400] [D loss: 0.086208] [G loss: 0.574375] [Elapsed time: 10215.05s]
# [Epoch 387/400] [D loss: 0.279858] [G loss: 0.678635] [Elapsed time: 10241.58s]
# [Epoch 388/400] [D loss: 0.270715] [G loss: 0.477751] [Elapsed time: 10268.28s]
# [Epoch 389/400] [D loss: 0.196581] [G loss: 0.028842] [Elapsed time: 10294.62s]
# [Epoch 390/400] [D loss: 0.324482] [G loss: 0.115208] [Elapsed time: 10320.96s]
# [Epoch 391/400] [D loss: 0.279097] [G loss: 0.342858] [Elapsed time: 10347.65s]
# [Epoch 392/400] [D loss: 0.176450] [G loss: 0.905720] [Elapsed time: 10374.79s]
# [Epoch 393/400] [D loss: 0.240927] [G loss: 0.639443] [Elapsed time: 10401.30s]
# [Epoch 394/400] [D loss: 0.118079] [G loss: 0.752436] [Elapsed time: 10428.03s]
# [Epoch 395/400] [D loss: 0.335583] [G loss: 0.161510] [Elapsed time: 10454.35s]
# [Epoch 396/400] [D loss: 0.220411] [G loss: 0.542748] [Elapsed time: 10480.94s]
# [Epoch 397/400] [D loss: 0.298579] [G loss: 0.037208] [Elapsed time: 10507.57s]
# [Epoch 398/400] [D loss: 0.359594] [G loss: 0.451863] [Elapsed time: 10534.02s]
# [Epoch 399/400] [D loss: 0.362406] [G loss: 0.835439] [Elapsed time: 10559.99s]

# %% [markdown]
# * 생성된 이미지 예시를 출력합니다.

# %%
from IPython.display import Image as Display

Display('./results/dcgan/28000.png')

# %% [markdown]
# * 다음의 코드를 이용하여 학습된 모델 파라미터를 저장할 수 있습니다.

# %%
# 모델 파라미터 저장
torch.save(dcgan_generator.state_dict(), "DCGAN_Generator_for_Face_Mask.pt")
torch.save(dcgan_discriminator.state_dict(), "DCGAN_Discriminator_for_Face_Mask.pt")
print("Model saved!")
# Out:
# Model saved!

# %% [markdown]
# * 학습된 모델 파라미터를 불러와 이미지 생성을 진행할 수 있습니다.

# %%
# 생성자(generator) 초기화
dcgan_generator = DCGANGenerator()
dcgan_generator.cuda()
dcgan_generator.load_state_dict(torch.load("DCGAN_Generator_for_Face_Mask.pt"))
dcgan_generator.eval()
# Out:
# DCGANGenerator(
#   (label_embed): Embedding(2, 2)
#   (layer1): Sequential(
#     (0): Linear(in_features=102, out_features=8192, bias=True)
#   )
#   (conv_blocks): Sequential(
#     (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (1): Upsample(scale_factor=2.0, mode=nearest)
#     (2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): BatchNorm2d(512, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Upsample(scale_factor=2.0, mode=nearest)
#     (6): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): BatchNorm2d(256, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (8): LeakyReLU(negative_slope=0.2, inplace=True)
#     (9): Upsample(scale_factor=2.0, mode=nearest)
#     (10): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (12): LeakyReLU(negative_slope=0.2, inplace=True)
#     (13): Upsample(scale_factor=2.0, mode=nearest)
#     (14): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(64, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (16): LeakyReLU(negative_slope=0.2, inplace=True)
#     (17): Conv2d(64, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): Tanh()
#   )
# )

# %% [markdown]
# * 마스크를 착용한 얼굴을 생성합니다.

# %%
from IPython.display import Image as Display

# 랜덤 노이즈(noise) 및 랜덤 레이블(label) 샘플링
z = torch.normal(mean=0, std=1, size=(100, latent_dim)).cuda()
generated_labels = torch.cuda.IntTensor(100).fill_(0)

# 이미지 생성
generated_imgs = dcgan_generator(z, generated_labels)

# 생성된 이미지 중에서 100개를 선택하여 10 X 10 격자 이미지에 출력
save_image(generated_imgs.data[:100], f'./results/dcgan/with_mask.png', nrow=10, normalize=True)

Display('./results/dcgan/with_mask.png')

# %% [markdown]
# * 마스크를 착용하지 않은 얼굴을 생성합니다.

# %%
from IPython.display import Image as Display

# 랜덤 노이즈(noise) 및 랜덤 레이블(label) 샘플링
z = torch.normal(mean=0, std=1, size=(100, latent_dim)).cuda()
generated_labels = torch.cuda.IntTensor(100).fill_(1)

# 이미지 생성
generated_imgs = dcgan_generator(z, generated_labels)

# 생성된 이미지 중에서 100개를 선택하여 10 X 10 격자 이미지에 출력
save_image(generated_imgs.data[:100], f'./results/dcgan/with_no_mask.png', nrow=10, normalize=True)

Display('./results/dcgan/with_no_mask.png')

# %% [markdown]
# #### <b>(알아보기) GAN 모델 평가하기 - FID Score</b>
#
# * 논문 제목: [Rethinking the Inception Architecture for Computer Vision](https://arxiv.org/abs/1512.00567) <b>(CVPR 2016)</b>
# * Fréchet Inception Distance(FID) 계산 방법
#     * <b>생성된 이미지</b>들과 <b>실제 이미지</b>들을 ImageNet에 넣어 특징(feature)을 추출합니다.
#     * 생성된 이미지 특징 분포 G와 실제 이미지 특징 분포 X를 가우시안 분포라고 가정합니다.
#     * 두 분포가 얼마나 다른지 계산하기 위해 FID(X, G)를 계산합니다.
# * [FID score for PyTorch](https://github.com/hukkelas/pytorch-frechet-inception-distance) 라이브러리를 이용해 간단히 계산할 수 있습니다.
#     * 다음과 같이 소스코드를 다운로드할 수 있습니다.

# %%
# !git clone https://github.com/hukkelas/pytorch-frechet-inception-distance
# Out:
# fatal: destination path 'pytorch-frechet-inception-distance' already exists and is not an empty directory.

# %% [markdown]
# * <b>Simple GAN</b>: FID 점수를 계산하기 위해 마스크 착용 및 마스크 미착용 이미지를 1,000장씩 생성합니다.

# %%
# !mkdir -p ./results/simple/with_mask
# !mkdir -p ./results/simple/without_mask

from IPython.display import Image as Display


# 마스크를 착용한 총 10 * 100개의 얼굴 이미지를 생성
for i in range(10):
    # 랜덤 노이즈(noise) 및 랜덤 레이블(label) 샘플링
    z = torch.normal(mean=0, std=1, size=(100, latent_dim)).cuda()
    generated_labels = torch.cuda.IntTensor(100).fill_(0)
    # 이미지 생성
    generated_imgs = simple_generator(z, generated_labels)

    for j in range(100):
        save_image(generated_imgs.data[j], f'./results/simple/with_mask/{i * 100 + j}.png', normalize=True)


# 마스크를 착용한 총 10 * 100개의 얼굴 이미지를 생성
for i in range(10):
    # 랜덤 노이즈(noise) 및 랜덤 레이블(label) 샘플링
    z = torch.normal(mean=0, std=1, size=(100, latent_dim)).cuda()
    generated_labels = torch.cuda.IntTensor(100).fill_(1)
    # 이미지 생성
    generated_imgs = simple_generator(z, generated_labels)

    for j in range(100):
        save_image(generated_imgs.data[j], f'./results/simple/without_mask/{i * 100 + j}.png', normalize=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [40], in <cell line: 8>()
#      13     generated_imgs = simple_generator(z, generated_labels)
#      15     for j in range(100):
# ---> 16         save_image(generated_imgs.data[j], f'./results/simple/with_mask/{i * 100 + j}.png', normalize=True)
#      19 # 마스크를 착용한 총 10 * 100개의 얼굴 이미지를 생성
#      20 for i in range(10):
#      21     # 랜덤 노이즈(noise) 및 랜덤 레이블(label) 샘플링
#
# File ~\anaconda3\lib\site-packages\torch\autograd\grad_mode.py:28, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      25 @functools.wraps(func)
#      26 def decorate_context(*args, **kwargs):
#      27     with self.__class__():
# ---> 28         return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\torchvision\utils.py:136, in save_image(tensor, fp, format, **kwargs)
#     134 ndarr = grid.mul(255).add_(0.5).clamp_(0, 255).permute(1, 2, 0).to('cpu', torch.uint8).numpy()
#     135 im = Image.fromarray(ndarr)
# --> 136 im.save(fp, format=format)
#
# File ~\anaconda3\lib\site-packages\PIL\Image.py:2209, in Image.save(self, fp, format, **params)
#    2207         fp = builtins.open(filename, "r+b")
#    2208     else:
# -> 2209         fp = builtins.open(filename, "w+b")
#    2211 try:
#    2212     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: './results/simple/with_mask/0.png'

# %% [markdown]
# * <b>DCGAN</b>: FID 점수를 계산하기 위해 마스크 착용 및 마스크 미착용 이미지를 1,000장씩 생성합니다.

# %%
# !mkdir -p ./results/dcgan/with_mask
# !mkdir -p ./results/dcgan/without_mask

from IPython.display import Image as Display


# 마스크를 착용한 총 10 * 100개의 얼굴 이미지를 생성
for i in range(10):
    # 랜덤 노이즈(noise) 및 랜덤 레이블(label) 샘플링
    z = torch.normal(mean=0, std=1, size=(100, latent_dim)).cuda()
    generated_labels = torch.cuda.IntTensor(100).fill_(0)
    # 이미지 생성
    generated_imgs = dcgan_generator(z, generated_labels)

    for j in range(100):
        save_image(generated_imgs.data[j], f'./results/dcgan/with_mask/{i * 100 + j}.png', normalize=True)


# 마스크를 착용한 총 10 * 100개의 얼굴 이미지를 생성
for i in range(10):
    # 랜덤 노이즈(noise) 및 랜덤 레이블(label) 샘플링
    z = torch.normal(mean=0, std=1, size=(100, latent_dim)).cuda()
    generated_labels = torch.cuda.IntTensor(100).fill_(1)
    # 이미지 생성
    generated_imgs = dcgan_generator(z, generated_labels)

    for j in range(100):
        save_image(generated_imgs.data[j], f'./results/dcgan/without_mask/{i * 100 + j}.png', normalize=True)

# %% [markdown]
# * 다음과 같이 <b>FID를 계산</b>할 수 있습니다.
#     * <b>FID 값이 낮을수록 우수한 모델</b>입니다.
# * 메모리 초과 오류(CUDA error: out of memory)가 발생할 수 있습니다.
#     * 메모리 초과가 발생할 때는 학습했던 GAN 네트워크를 잘 저장한 뒤에 <b>[런타임]</b> - <b>[런타임 다시 시작]</b>을 진행합니다.
# * Simple GAN의 마스크 미착용 FID 점수: 247.69
# * Simple GAN의 마스크 착용 FID 점수: 320.88
# * DCGAN의 마스크 미착용 FID 점수: 171.67
# * DCGAN의 마스크 착용 FID 점수: 114.97
#
# * 100 에팍 171 101
# * 200 에팍 164 90
# * 300 에팍 146 101
# * 400 에팍 156 93
# * 500 에팍 160 94
# * 200 100 d에팍 167 127

# %%
# !python ./pytorch-frechet-inception-distance/fid.py --path1 ./results/simple/without_mask --path2 ./Face-Mask-Classification-20000-Dataset/test/without_mask --batch-size 32
# Out:
# Traceback (most recent call last):
#   File "./pytorch-frechet-inception-distance/fid.py", line 275, in <module>
#     images1 = load_images(options.path1)
#   File "./pytorch-frechet-inception-distance/fid.py", line 243, in load_images
#     first_image = cv2.imread(image_paths[0])
# IndexError: list index out of range

# %%
# !python ./pytorch-frechet-inception-distance/fid.py --path1 ./results/simple/with_mask --path2 ./Face-Mask-Classification-20000-Dataset/test/with_mask --batch-size 32
# Out:
# Traceback (most recent call last):
#   File "./pytorch-frechet-inception-distance/fid.py", line 275, in <module>
#     images1 = load_images(options.path1)
#   File "./pytorch-frechet-inception-distance/fid.py", line 243, in load_images
#     first_image = cv2.imread(image_paths[0])
# IndexError: list index out of range

# %%
# !python ./pytorch-frechet-inception-distance/fid.py --path1 ./results/dcgan/without_mask --path2 ./Face-Mask-Classification-20000-Dataset/test/without_mask --batch-size 32
# !python ./pytorch-frechet-inception-distance/fid.py --path1 ./results/dcgan/without_mask --path2 ./Face-Mask-Classification-20000-Dataset/test/without_mask --batch-size 16
# Out:
# 156.85423294273065

# %%
# !python ./pytorch-frechet-inception-distance/fid.py --path1 ./results/dcgan/with_mask --path2 ./Face-Mask-Classification-20000-Dataset/test/with_mask --batch-size 16
# Out:
# 93.83373026851606

# %% [markdown]
# #### <b>Problem 1. 나만의 모델을 만들어 학습 및 평가하기</b>
#
# * 나만의 GAN 모델을 이용해 <b>최대한 높은 FID 점수</b>를 받아보세요.
#     * (Hint) 200 epochs 이상으로 학습해보기
#     * (Hint) DCGAN의 아키텍처를 효율적으로 바꿔보기
#     * (Hint) WGAN 등 [다른 아키텍처들을](https://github.com/eriklindernoren/PyTorch-GAN) 적용해보기
#     * (Hint) 사전 학습된(pre-trained) GAN 모델 사용해보기
# * 결과적으로 자신이 학습한 모델의 <b>최종 FID 점수(score)를 작성</b>하세요.
#     * 마스크 착용 및 미착용 이미지를 <b>각각 1,000장씩 생성</b>하여 FID를 계산합니다.
#     * 마스크 착용: {답을 쓰세요.}
#     * 마스크 미착용: {답을 쓰세요.}
# * 결과 이미지의 해상도는 1 X 64 X 64가 되어야 합니다.

# %%
# 생성자(Generator) 클래스 정의
class CustomGenerator(nn.Module):
    def __init__(self):
        super(CustomGenerator, self).__init__()
        # 적절한 소스코드를 작성하세요.
        pass

    def forward(self, noise, labels):
        # 적절한 소스코드를 작성하세요.
        pass


# 판별자(Discriminator) 클래스 정의
class CustomDiscriminator(nn.Module):
    def __init__(self):
        super(CustomDiscriminator, self).__init__()
        # 적절한 소스코드를 작성하세요.
        pass

    # 이미지에 대한 판별 결과를 반환
    def forward(self, img, labels):
        # 적절한 소스코드를 작성하세요.
        pass

# %%
# 모델 학습하는 코드 작성하기
pass

# %%
# 평가 수행
# !python ./pytorch-frechet-inception-distance/fid.py --path1 ./results/custom/without_mask --path2 ./Face-Mask-Classification-20000-Dataset/test/without_mask --batch-size 32

# %%
# 평가 수행
# !python ./pytorch-frechet-inception-distance/fid.py --path1 ./results/custom/with_mask --path2 ./Face-Mask-Classification-20000-Dataset/test/with_mask --batch-size 32

# %%
# ./results/custom/ 폴더의 모든 파일을 results.zip라는 이름으로 압축
# !zip ./results.zip -r ./results/custom/*

# %%
# Google Colab으로부터 results.zip 압축 파일 다운로드
from google.colab import files

files.download('./results.zip')

# %% [markdown]
# * PPT에 들어갈 내용
#     1. 최종적으로 얻은 점수 (마스크 미착용 FID 점수 + 마스크 착용 FID 점수)
#     2. 좋은 결과를 만들기 위해 어떤 전략을 사용했는지, 그 이유는 무엇인지
#     3. 소스코드에서 핵심이 되는 부분 캡처 사진 및 설명
#     4. 자신의 GAN에서 생성된 이미지들 캡처 사진
# * 점수 판정 기준
#     * <b>FID의 점수 합이 가장 작은 팀</b>이 1등입니다.
#     * 마스크 미착용 FID 점수 = 171.67이고, 마스크 착용 FID 점수 = 114.97이라면?
#     * 최종 점수 = 171.67 + 114.97 = 286.64
# * 최종적으로 <b>팀 단위로 제출할 파일</b>은 다음과 같습니다.
#     1. PPT 파일: 사용한 모델과 최종적인 FID 점수에 대한 설명을 포함하기
#     2. Colab Notebook 파일: <b>[파일]</b> - <b>[다운로드]</b> - <b>[.ipynb 다운로드]</b>
#     3. 최종 결과 이미지(마스크 착용 1,000개 및 마스크 미착용 1,000개)가 포함된 압축 파일
# * 최종 결과 이미지는 다음과 같은 양식으로 압축 파일(.zip) 형태로 제출합니다.
#     * with_mask와 without_mask 이미지들이 서로 다른 폴더로 확실히 구분되어야 합니다.
#     * <b>PPT에 기록된 FID 점수와 동일한 점수</b>가 나오는 이미지여야 합니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * GAN은 학습이 어려운 네트워크 중 하나입니다.
#     * 학습 자체가 안 되는 문제가 발생할 수 있습니다. (처음부터 D loss: 0.5, G loss: 1.0 고정되는 문제)
#     * 같은 레이블에 대하여 거의 똑같은 이미지만 생성될 수 있습니다. (mode collapse)
# * (Hint) 학습이 잘 안 되는 경우 배치 사이즈, learning rate, 아키텍처를 다시 확인하고 조절합니다.
# * FID 점수는 이미지 생성을 할 때마다 변경될 수 있습니다.
#     * 실제로 해당 FID 점수가 나왔는지 확인할 필요가 있으므로, 생성된 이미지 파일(총 2,000장)을 꼭 함께 제출합니다.
